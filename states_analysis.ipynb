# %%
import pandas as pd

# %%
df = pd.read_csv('./datasets/states.csv')

# %%
df
# Out:
#                 State  Per Capita NSDP at 2004-05 prices (Rs.)  \
# 0           All India                                    38856
# 1      Andhra Pradesh                                    44526
# 2               Bihar                                    14362
# 3   Arunachal Pradesh                                    35845
# 4      Madhya Pradesh                                    25463
# 5        Chhattisgarh                                    27421
# 6       Uttar Pradesh                                    18595
# 7         Maharashtra                                    64218
# 8               Assam                                    23448
# 9         West Bengal                                    33889
# 10              Delhi                                   118960
# 11             Kerala                                    56115
# 12              J & K                                    29754
# 13            Gujarat                                    61220
# ...

# %%
df.shape
# Out:
# (29, 42)

# %%
df.columns
# Out:
# Index(['State', 'Per Capita NSDP at 2004-05 prices (Rs.)',
#        'Growth in Per Capita NSDP at 2004-05 prices (%)',
#        'Growth rate in GSDP-Total', 'Growth rate in GSDP-Agriculture',
#        'Growth rate in GSDP-Industry', 'Growth rate in GSDP-services',
#        'Area (Sq. Km.)', 'Population (crore)',
#        'Population Density (Per Sq. Km.)',
#        'Decadal Growth Rate of Population (2001-2011) (%)',
#        'Sex Ratio (Females/ 1000 Males)',
#        'Sex Ratio (0-6 years) (Female children/ 1000 male children)',
#        'Total Literacy Rate (%)', 'Male (%)', 'Female (%)',
#        'Gender Gap in Literacy (%)',
#        'Infant Mortality Rate (IMR) (per 1000 live births)',
#        'Maternal Mortality Rate (MMR) (per 100000 live births)',
#        'Total Fertility Rate (TFR) (Birth/ woman)',
#        'Neo Natal Mortality Rate (NMR) (per 1000 live births)',
#        'Under 5 Mortality Rate (U-5MR) (per 1000 live births)',
# ...

# %%
df.describe()
# Out:
#        Per Capita NSDP at 2004-05 prices (Rs.)  \
# count                                29.000000
# mean                              45245.931034
# std                               26329.633967
# min                               14362.000000
# 25%                               27421.000000
# 50%                               39347.000000
# 75%                               54462.000000
# max                              132121.000000
#
#        Growth in Per Capita NSDP at 2004-05 prices (%)  \
# count                                        29.000000
# mean                                          4.191034
# std                                           2.570348
# min                                          -1.510000
# 25%                                           2.860000
# 50%                                           3.820000
# 75%                                           5.360000
# max                                           9.230000
#
# ...

# %%
df.head()
# Out:
#                State  Per Capita NSDP at 2004-05 prices (Rs.)  \
# 0          All India                                    38856
# 1     Andhra Pradesh                                    44526
# 2              Bihar                                    14362
# 3  Arunachal Pradesh                                    35845
# 4     Madhya Pradesh                                    25463
#
#    Growth in Per Capita NSDP at 2004-05 prices (%)  Growth rate in GSDP-Total  \
# 0                                             2.12                       4.70
# 1                                             4.55                       5.09
# 2                                             9.23                      10.74
# 3                                             1.74                       4.64
# 4                                             8.60                       9.89
#
#    Growth rate in GSDP-Agriculture  Growth rate in GSDP-Industry  \
# ...

# %%
df[1:].describe()
# Out:
#        Per Capita NSDP at 2004-05 prices (Rs.)  \
# count                                28.000000
# mean                              45474.142857
# std                               26783.563243
# min                               14362.000000
# 25%                               27318.250000
# 50%                               40831.000000
# 75%                               54875.250000
# max                              132121.000000
#
#        Growth in Per Capita NSDP at 2004-05 prices (%)  \
# count                                        28.000000
# mean                                          4.265000
# std                                           2.585894
# min                                          -1.510000
# 25%                                           3.107500
# 50%                                           3.870000
# 75%                                           5.662500
# max                                           9.230000
#
# ...

# %%
df[1:]
# Out:
#                 State  Per Capita NSDP at 2004-05 prices (Rs.)  \
# 1      Andhra Pradesh                                    44526
# 2               Bihar                                    14362
# 3   Arunachal Pradesh                                    35845
# 4      Madhya Pradesh                                    25463
# 5        Chhattisgarh                                    27421
# 6       Uttar Pradesh                                    18595
# 7         Maharashtra                                    64218
# 8               Assam                                    23448
# 9         West Bengal                                    33889
# 10              Delhi                                   118960
# 11             Kerala                                    56115
# 12              J & K                                    29754
# 13            Gujarat                                    61220
# 14           Nagaland                                    48111
# ...

# %%
df['Safe Drinking Water (Tap/Handpump/Tubewell) (%age)']
# Out:
# 0     85.5
# 1     90.5
# 2     94.0
# 3     78.6
# 4     78.0
# 5     86.3
# 6     95.1
# 7     83.4
# 8     69.9
# 9     92.2
# 10    95.0
# 11    33.5
# 12    76.8
# 13    90.3
# 14    53.8
# 15    97.6
# 16    67.5
# 17    60.1
# 18    92.2
# 19    87.5
# 20    93.7
# 21    93.8
# 22    60.4
# 23    45.4
# 24    85.7
# 25    44.7
# 26    92.5
# 27    75.3
# 28    78.1
# Name: Safe Drinking Water (Tap/Handpump/Tubewell) (%age), dtype: float64

# %%
df['Safe Drinking Water (Tap/Handpump/Tubewell) (%age)'][1:]
# Out:
# 1     90.5
# 2     94.0
# 3     78.6
# 4     78.0
# 5     86.3
# 6     95.1
# 7     83.4
# 8     69.9
# 9     92.2
# 10    95.0
# 11    33.5
# 12    76.8
# 13    90.3
# 14    53.8
# 15    97.6
# 16    67.5
# 17    60.1
# 18    92.2
# 19    87.5
# 20    93.7
# 21    93.8
# 22    60.4
# 23    45.4
# 24    85.7
# 25    44.7
# 26    92.5
# 27    75.3
# 28    78.1
# Name: Safe Drinking Water (Tap/Handpump/Tubewell) (%age), dtype: float64

# %%
df[['State','Safe Drinking Water (Tap/Handpump/Tubewell) (%age)']][df['Safe Drinking Water (Tap/Handpump/Tubewell) (%age)']<78]
# Out:
#         State  Safe Drinking Water (Tap/Handpump/Tubewell) (%age)
# 8       Assam                                               69.9
# 11     Kerala                                               33.5
# 12      J & K                                               76.8
# 14   Nagaland                                               53.8
# 16    Tripura                                               67.5
# 17  Jharkhand                                               60.1
# 22    Mizoram                                               60.4
# 23    Manipur                                               45.4
# 25  Meghalaya                                               44.7
# 27     Odisha                                               75.3

# %%
df[['State','Forest Cover (% of geographical area)']][df['Forest Cover (% of geographical area)']<50].sort_values(by='Forest Cover (% of geographical area)')
# Out:
#              State  Forest Cover (% of geographical area)
# 15          Punjab                                    3.5
# 21         Haryana                                    3.6
# 28       Rajasthan                                    4.7
# 6    Uttar Pradesh                                    6.0
# 13         Gujarat                                    7.5
# 2            Bihar                                    7.7
# 12           J & K                                   10.1
# 10           Delhi                                   12.1
# 7      Maharashtra                                   16.5
# 1   Andhra Pradesh                                   16.8
# 26      Tamil Nadu                                   18.3
# 19       Karnataka                                   18.8
# 9      West Bengal                                   18.9
# 0        All India                                   21.2
# 4   Madhya Pradesh                                   25.2
# ...

# %%
#concatenate multiple function
#to_csv,sort_values
#applying multiple functions to slice the dataset
df[['State','Forest Cover (% of geographical area)']][df['Forest Cover (% of geographical area)']<50].sort_values(by='Forest Cover (% of geographical area)').head(5)
# Out:
#             State  Forest Cover (% of geographical area)
# 15         Punjab                                    3.5
# 21        Haryana                                    3.6
# 28      Rajasthan                                    4.7
# 6   Uttar Pradesh                                    6.0
# 13        Gujarat                                    7.5

# %%
new_df = df[['State','Forest Cover (% of geographical area)']][df['Forest Cover (% of geographical area)']<50]

# %%
new_df.plot()

# %%
new_df.plot(x="State",kind="barh",color="green")

# %%
new_df.plot(x="State",kind="barh",color="green",title="New Chart")

# %%
new_df1= df[['State','Forest Cover (% of geographical area)']][df['Forest Cover (% of geographical area)']<50].sort_values(by ='Forest Cover (% of geographical area)').tail(5)

# %%
new_df1.plot(kind="barh",x="State",color="green",title="new plot2")

# %%
new_df2 = df[['State','Forest Cover (% of geographical area)']][df['Forest Cover (% of geographical area)']>50].sort_values(by='Forest Cover (% of geographical area)')

# %%
new_df2.plot(kind='barh',color='green',x='State')

# %%
new_df3= df[['State','Forest Cover (% of geographical area)']][df['Forest Cover (% of geographical area)']>50].sort_values(by='Forest Cover (% of geographical area)',ascending=False)
new_df3
# Out:
#                 State  Forest Cover (% of geographical area)
# 22            Mizoram                                   90.4
# 3   Arunachal Pradesh                                   80.4
# 14           Nagaland                                   78.7
# 25          Meghalaya                                   77.1
# 23            Manipur                                   76.1
# 16            Tripura                                   75.0
# 24                Goa                                   59.9

# %%
new_df3.plot(kind='barh',x='State',title="Max forest cover states",legend=False)

# %%
new_df3
# Out:
#                 State  Forest Cover (% of geographical area)
# 22            Mizoram                                   90.4
# 3   Arunachal Pradesh                                   80.4
# 14           Nagaland                                   78.7
# 25          Meghalaya                                   77.1
# 23            Manipur                                   76.1
# 16            Tripura                                   75.0
# 24                Goa                                   59.9
